# %% [markdown]
# # FIFA 21 Dataset: Data Analysis ⚽

# %% [markdown]
# This is the second part of the project where I'll perform some analysis in the (now cleaned) data.
#
# The data cleaning process is in another file: 'FIFA21 data cleaning.ipynb'

# %% [markdown]
# ## Importing the data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 100)

# %%
sns.set_palette("deep",10)
sns.set_style("darkgrid")

# %%
fifa = pd.read_csv('/home/daniel-ubuntu/Desktop/FIFA21/datasets/fifa21 cleaned data(1.0).csv')
fifa.drop('Unnamed: 0', axis=1, inplace=True)
fifa.head()
# Out:
#        ID               Name                      Fullname Nationality  Age
# 0  158023           L. Messi                  Lionel Messi   Argentina   33  \
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal   35
# 2  200389           J. Oblak                     Jan Oblak    Slovenia   27
# 3  192985       K. De Bruyne               Kevin De Bruyne     Belgium   29
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.      Brazil   28
#
#    OVA  POT                 Club     Contract Contract Start Contract End
# 0   93   93         FC Barcelona  2004 ~ 2021           2004         2021  \
# 1   92   92             Juventus  2018 ~ 2022           2018         2022
# 2   91   93      Atlético Madrid  2014 ~ 2023           2014         2023
# 3   91   91      Manchester City  2015 ~ 2023           2015         2023
# 4   91   91  Paris Saint-Germain  2017 ~ 2022           2017         2022
#
# ...

# %% [markdown]
# ## Initial Analysis

# %%
fifa.describe().round()
# Out:
#              ID      Age      OVA      POT  Height (in cm)  Weight (in kg)
# count   18979.0  18979.0  18979.0  18979.0         18979.0         18979.0  \
# mean   226403.0     25.0     66.0     71.0           181.0            75.0
# std     27141.0      5.0      7.0      6.0             7.0             7.0
# min        41.0     16.0     47.0     47.0           155.0            50.0
# 25%    210135.0     21.0     61.0     67.0           176.0            70.0
# 50%    232418.0     25.0     66.0     71.0           181.0            75.0
# 75%    246922.0     29.0     70.0     75.0           186.0            80.0
# max    259216.0     53.0     93.0     95.0           206.0           110.0
#
#            BOV     Year      Day  Value (EUR)  Wage (EUR)
# count  18979.0  18979.0  18979.0      18979.0     18979.0  \
# mean      67.0   2018.0     10.0    2865063.0    128697.0
# std        7.0      2.0     10.0    7685154.0    248274.0
# ...

# %% [markdown]
# Some interesting data from the '.describe()':
# *   **Age:** Average = 25, Min = 16 , Max = 53
# *   **Overall:** Max = 93 , Min = 47
# *   **Potential:** Max = 95
# *   **Height:** Average = 181, Min = 155 , Max = 206
# *   **Weight:** Average = 75, Min = 50 , Max = 110
# *   **Player Value:** Average = 2.865063e+06, Min = 0 , Max = 1.855000e+08
# *   **Player Salary:** Average = 128696, Min = 0 , Max = 950000
# *   **Release Clause:** Average = 3.962951e+06, Min = 0 , Max = 2.031000e+08
# *   **Weak Foot:** Average = 2.940513
# *   **Skills Move:** Average = 2.364982
#
#        <img src="/home/daniel-ubuntu/Desktop/FIFA21/Average Player.png" alt="Average Player" width="300" height="300">

# %% [markdown]
# ### Searching for some players

# %%
#The oldest player in the game
fifa[fifa['Age'] == 53]
# Out:
#            ID      Name         Fullname Nationality  Age  OVA  POT
# 16109  254704  K. Miura  Kazuyoshi Miura       Japan   53   59   59  \
#
#               Club     Contract Contract Start Contract End Positions
# 16109  Yokohama FC  2005 ~ 2021           2005         2021        ST  \
#
#        Height (in cm)  Weight (in kg) Preferred Foot  BOV Best Position
# 16109           177.0            72.0          Right   60            CF  \
#
#            Joined  Year Month  Day Loan Date End  Value (EUR)  Wage (EUR)
# 16109  2005-07-01  2005   Jul    1           NaN            0      700000  \
#
#        Release Clause (EUR)  Attacking  Crossing  Finishing  Heading Accuracy
# 16109                     0        289        44         66                56  \
#
#        Short Passing  Volleys  Skill  Dribbling  Curve  FK Accuracy
# 16109             61       62    290         63     69           54  \
#
#        Long Passing  Ball Control  Movement  Acceleration  Sprint Speed
# ...

# %%
#The player with the highest Overall in the game
fifa[fifa['OVA'] == 93]
# Out:
#        ID      Name      Fullname Nationality  Age  OVA  POT          Club
# 0  158023  L. Messi  Lionel Messi   Argentina   33   93   93  FC Barcelona  \
#
#       Contract Contract Start Contract End   Positions  Height (in cm)
# 0  2004 ~ 2021           2004         2021  RW, ST, CF           170.0  \
#
#    Weight (in kg) Preferred Foot  BOV Best Position      Joined  Year Month
# 0            72.0           Left   93            RW  2004-07-01  2004   Jul  \
#
#    Day Loan Date End  Value (EUR)  Wage (EUR)  Release Clause (EUR)
# 0    1           NaN    103500000      560000             138400000  \
#
#    Attacking  Crossing  Finishing  Heading Accuracy  Short Passing  Volleys
# 0        429        85         95                70             91       88  \
#
#    Skill  Dribbling  Curve  FK Accuracy  Long Passing  Ball Control  Movement
# 0    470         96     93           94            91            96       451  \
#
# ...

# %%
#And the total of players with the lowest Overall
len(fifa[fifa['OVA'] == 53])
# Out:
# 235

# %%
#The player with the highest potential in the game
fifa[fifa['POT'] == 95]
# Out:
#        ID       Name       Fullname Nationality  Age  OVA  POT
# 8  231747  K. Mbappé  Kylian Mbappé      France   21   90   95  \
#
#                   Club     Contract Contract Start Contract End   Positions
# 8  Paris Saint-Germain  2018 ~ 2022           2018         2022  ST, LW, RW  \
#
#    Height (in cm)  Weight (in kg) Preferred Foot  BOV Best Position
# 8           178.0            73.0          Right   91            ST  \
#
#        Joined  Year Month  Day Loan Date End  Value (EUR)  Wage (EUR)
# 8  2018-07-01  2018   Jul    1           NaN    185500000      160000  \
#
#    Release Clause (EUR)  Attacking  Crossing  Finishing  Heading Accuracy
# 8             203100000        408        78         91                73  \
#
#    Short Passing  Volleys  Skill  Dribbling  Curve  FK Accuracy  Long Passing
# 8             83       83    394         92     79           63            70  \
#
#    Ball Control  Movement  Acceleration  Sprint Speed  Agility  Reactions
# ...

# %%
#Highest player according FIFA
fifa[fifa['Height (in cm)'] == 206]
# Out:
#            ID     Name    Fullname     Nationality  Age  OVA  POT
# 10333  199321  T. Holý  Tomáš Holý  Czech Republic   28   65   67  \
#
#                Club     Contract Contract Start Contract End Positions
# 10333  Ipswich Town  2019 ~ 2022           2019         2022        GK  \
#
#        Height (in cm)  Weight (in kg) Preferred Foot  BOV Best Position
# 10333           206.0           102.0          Right   65            GK  \
#
#            Joined  Year Month  Day Loan Date End  Value (EUR)  Wage (EUR)
# 10333  2019-07-01  2019   Jul    1           NaN       600000        3000  \
#
#        Release Clause (EUR)  Attacking  Crossing  Finishing  Heading Accuracy
# 10333                867000         87        13         18                18  \
#
#        Short Passing  Volleys  Skill  Dribbling  Curve  FK Accuracy
# 10333             18       20     98         16     20           14  \
#
#        Long Passing  Ball Control  Movement  Acceleration  Sprint Speed
# ...

# %%
#And the lowest player 
fifa[fifa['Height (in cm)'] == 155]
# Out:
#            ID         Name         Fullname Nationality  Age  OVA  POT
# 12971  232951  H. Nakagawa  Hiroto Nakagawa       Japan   25   63   66  \
#
#                   Club     Contract Contract Start Contract End    Positions
# 12971  Shonan Bellmare  2020 ~ 2023           2020         2023  CAM, ST, CM  \
#
#        Height (in cm)  Weight (in kg) Preferred Foot  BOV Best Position
# 12971           155.0            57.0          Right   66            RM  \
#
#            Joined  Year Month  Day Loan Date End  Value (EUR)  Wage (EUR)
# 12971  2020-02-01  2020   Feb    1           NaN       625000        1000  \
#
#        Release Clause (EUR)  Attacking  Crossing  Finishing  Heading Accuracy
# 12971                629000        260        45         54                38  \
#
#        Short Passing  Volleys  Skill  Dribbling  Curve  FK Accuracy
# 12971             60       63    303         64     70           55  \
#
# ...

# %%
#The lightiest player in the game
fifa[fifa['Weight (in kg)'] == 50]
# Out:
#            ID           Name           Fullname   Nationality  Age  OVA  POT
# 11149  235600  B. Al Mutairi  Bandar Al Mutairi  Saudi Arabia   30   64   64  \
#
#            Club     Contract Contract Start Contract End Positions
# 11149  Al Fayha  2019 ~ 2022           2019         2022        LB  \
#
#        Height (in cm)  Weight (in kg) Preferred Foot  BOV Best Position
# 11149           168.0            50.0           Left   64            LB  \
#
#            Joined  Year Month  Day Loan Date End  Value (EUR)  Wage (EUR)
# 11149  2019-07-06  2019   Jul    6           NaN       500000        5000  \
#
#        Release Clause (EUR)  Attacking  Crossing  Finishing  Heading Accuracy
# 11149                578000        211        61         22                41  \
#
#        Short Passing  Volleys  Skill  Dribbling  Curve  FK Accuracy
# 11149             56       31    251         55     57           38  \
#
#        Long Passing  Ball Control  Movement  Acceleration  Sprint Speed
# ...

# %%
#The heaviest and also the strongest player in the game
fifa[fifa['Weight (in kg)'] == 110]
# Out:
#            ID          Name           Fullname Nationality  Age  OVA  POT
# 10272  156321  A. Akinfenwa  Adebayo Akinfenwa     England   38   65   65  \
#
#                     Club     Contract Contract Start Contract End Positions
# 10272  Wycombe Wanderers  2016 ~ 2021           2016         2021        ST  \
#
#        Height (in cm)  Weight (in kg) Preferred Foot  BOV Best Position
# 10272           178.0           110.0          Right   65            ST  \
#
#            Joined  Year Month  Day Loan Date End  Value (EUR)  Wage (EUR)
# 10272  2016-07-10  2016   Jul   10           NaN       240000        3000  \
#
#        Release Clause (EUR)  Attacking  Crossing  Finishing  Heading Accuracy
# 10272                352000        301        44         64                74  \
#
#        Short Passing  Volleys  Skill  Dribbling  Curve  FK Accuracy
# 10272             60       59    262         50     50           42  \
#
# ...

# %% [markdown]
# ### Plotting the 'Height' and 'Weight' distributions

# %%
plt.figure(figsize=(20,9))
plt.subplot(1, 2, 1)  
ax = sns.histplot(data = fifa, x='Height (in cm)', kde= True, linewidth=0.6)
ax.set_title('Height (in cm) Distribution in FIFA 21', fontsize=26, loc='left')
ax.set_ylabel('Count', fontsize=20)
ax.set_xlabel('Height (in cm)', fontsize=20)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)
ax=ax

plt.subplot(1, 2, 2)
ax2 = sns.histplot(data = fifa, x='Weight (in kg)', kde = True,linewidth=0.6)
ax2.set_title('Weight (in kg) Distribution in FIFA 21', fontsize=26, loc='left')
ax2.set_ylabel('Count', fontsize=20)
ax2.set_xlabel('Weight (in Kg)', fontsize=20)
ax2.tick_params(axis='x', labelsize=20)
ax2.tick_params(axis='y', labelsize=20)
ax2=ax2

plt.tight_layout()

# %% [markdown]
# As we can see, in both variables, they almost follow a normal distribution. This is to be expected, as most football players must have a strict diet and tend to do a lot of physical exercise (that said in relation to the weight of the players). Now regarding their height, the vast majority of them are between 175 and 190 cm.

# %% [markdown]
# ### Searching for some more players

# %%
#Most Valuable player in the game
fifa[fifa['Value (EUR)'] == fifa['Value (EUR)'].max()]
# Out:
#        ID       Name       Fullname Nationality  Age  OVA  POT
# 8  231747  K. Mbappé  Kylian Mbappé      France   21   90   95  \
#
#                   Club     Contract Contract Start Contract End   Positions
# 8  Paris Saint-Germain  2018 ~ 2022           2018         2022  ST, LW, RW  \
#
#    Height (in cm)  Weight (in kg) Preferred Foot  BOV Best Position
# 8           178.0            73.0          Right   91            ST  \
#
#        Joined  Year Month  Day Loan Date End  Value (EUR)  Wage (EUR)
# 8  2018-07-01  2018   Jul    1           NaN    185500000      160000  \
#
#    Release Clause (EUR)  Attacking  Crossing  Finishing  Heading Accuracy
# 8             203100000        408        78         91                73  \
#
#    Short Passing  Volleys  Skill  Dribbling  Curve  FK Accuracy  Long Passing
# 8             83       83    394         92     79           63            70  \
#
#    Ball Control  Movement  Acceleration  Sprint Speed  Agility  Reactions
# ...

# %%
#Number of players available in the market for free (just has to pay to the player itself, like salary)
len(fifa[fifa['Value (EUR)'] == fifa['Value (EUR)'].min()])
# Out:
# 248

# %%
#Number of players with the highest wage
len(fifa[fifa['Wage (EUR)'] == fifa['Wage (EUR)'].max()])
# Out:
# 168

# %%
#Number of players with the wage = 0
len(fifa[fifa['Wage (EUR)'] == 0])
# Out:
# 237

# %%
#The player with the highest Release Clause
fifa[fifa['Release Clause (EUR)'] == fifa['Release Clause (EUR)'].max()]
# Out:
#        ID       Name       Fullname Nationality  Age  OVA  POT
# 8  231747  K. Mbappé  Kylian Mbappé      France   21   90   95  \
#
#                   Club     Contract Contract Start Contract End   Positions
# 8  Paris Saint-Germain  2018 ~ 2022           2018         2022  ST, LW, RW  \
#
#    Height (in cm)  Weight (in kg) Preferred Foot  BOV Best Position
# 8           178.0            73.0          Right   91            ST  \
#
#        Joined  Year Month  Day Loan Date End  Value (EUR)  Wage (EUR)
# 8  2018-07-01  2018   Jul    1           NaN    185500000      160000  \
#
#    Release Clause (EUR)  Attacking  Crossing  Finishing  Heading Accuracy
# 8             203100000        408        78         91                73  \
#
#    Short Passing  Volleys  Skill  Dribbling  Curve  FK Accuracy  Long Passing
# 8             83       83    394         92     79           63            70  \
#
#    Ball Control  Movement  Acceleration  Sprint Speed  Agility  Reactions
# ...

# %%
#Number of players with no Release Clause
len(fifa[fifa['Release Clause (EUR)'] == fifa['Release Clause (EUR)'].min()])
# Out:
# 1261

# %% [markdown]
# ### Plotting the 'Weak Foot' and 'Skill Move' distributions

# %%
plt.figure(figsize=(20,9))
plt.subplot(1, 2, 1)  
ax = sns.histplot(data = fifa, x='W/F', binwidth=0.4)
ax.set_title('Weak Foot stars Distribution in FIFA 21', fontsize=26, loc='left')
ax.set_ylabel('Number of players', fontsize=20)
ax.set_xlabel('Weak Foot stars', fontsize=20)
ax.set_xticks([1, 2, 3, 4, 5])
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)
ax=ax

plt.subplot(1, 2, 2)
ax2 = sns.histplot(data = fifa, x='SM',binwidth=0.4)
ax2.set_title('Skill Moves stars Distribution in FIFA 21', fontsize=26, loc='left')
ax2.set_ylabel('Number of players', fontsize=20)
ax2.set_xlabel('Skill Moves stars', fontsize=20)
ax2.set_xticks([1, 2, 3, 4, 5])
ax2.tick_params(axis='x', labelsize=20)
ax2.tick_params(axis='y', labelsize=20)
ax2=ax2

plt.tight_layout()

# %%
five_starswf = len(fifa[fifa['W/F'] == 5])
five_starssm = len(fifa[fifa['SM'] == 5])
#Decided to print it because we are not able to see it clearly in the graphs
print(f"The number of players with 5 stars of Weak Foot is {five_starswf}, thats equivalent to {round((five_starswf / len(fifa['W/F'])) * 100, 2)}% of the dataset")
print(f"The number of players with 5 stars of Skill Move is {five_starssm}', thats equivalent to {round((five_starssm / len(fifa['SM'])) * 100, 2)}% of the dataset")
# Out:
# The number of players with 5 stars of Weak Foot is 283, thats equivalent to 1.49% of the dataset
# The number of players with 5 stars of Skill Move is 55', thats equivalent to 0.29% of the dataset
